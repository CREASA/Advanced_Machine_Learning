# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
np.random.seed(123)

# %%
df_data  = pd.read_csv('week7_lab_data.csv')
all_features = ['crim', 'zn', 'indus',  'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax', 'ptratio', 'b', 'lstat']
X = df_data[all_features]
y = df_data["medv"]

# %% [markdown]
# # Forward and Backward Stepwise Selection

# %%
from sklearn.linear_model import LinearRegression
from mlxtend.feature_selection import SequentialFeatureSelector
from mlxtend.plotting import plot_sequential_feature_selection

# %%
feature_cols = ['crim', 'nox', 'rm',  'dis', 'rad', 'tax', 'ptratio', 'lstat']
X = df_data[feature_cols]
y = df_data["medv"]

# %%
lr = LinearRegression()

sfs_forward = SequentialFeatureSelector(lr, 
          k_features=len(feature_cols), 
          forward=True, 
          floating=False, 
          scoring='neg_mean_squared_error',
          cv=5)

sfs_forward = sfs_forward.fit(X, y)

fig_forward = plot_sequential_feature_selection(sfs_forward.get_metric_dict(), kind='std_err')

plt.title('Sequential Forward Selection (w. StdErr)')
plt.grid()
plt.ylim((-60,-20))
plt.show()

for k, items in sfs_forward.subsets_.items():
    print(f"{k} features: ", items["feature_names"])
# Out:
# 1 features:  ('lstat',)
# 2 features:  ('ptratio', 'lstat')
# 3 features:  ('rm', 'ptratio', 'lstat')
# 4 features:  ('crim', 'rm', 'ptratio', 'lstat')
# 5 features:  ('crim', 'rm', 'dis', 'ptratio', 'lstat')
# 6 features:  ('crim', 'nox', 'rm', 'dis', 'ptratio', 'lstat')
# 7 features:  ('crim', 'nox', 'rm', 'dis', 'tax', 'ptratio', 'lstat')
# 8 features:  ('crim', 'nox', 'rm', 'dis', 'rad', 'tax', 'ptratio', 'lstat')

# %%
lr = LinearRegression()

sfs_backward = SequentialFeatureSelector(lr, 
          k_features=1, 
          forward=False, 
          floating=False, 
          scoring='neg_mean_squared_error',
          cv=5)

sfs_backward = sfs_backward.fit(X, y)
fig_backward = plot_sequential_feature_selection(sfs_backward.get_metric_dict(), kind='std_err')

plt.title('Sequential Backward Selection (w. StdErr)')
plt.ylim((-60,-20))
plt.grid()
plt.show()

for k, items in sfs_backward.subsets_.items():
    print(f"{k} features: ", items["feature_names"])
# Out:
# 8 features:  ('crim', 'nox', 'rm', 'dis', 'rad', 'tax', 'ptratio', 'lstat')
# 7 features:  ('crim', 'nox', 'dis', 'rad', 'tax', 'ptratio', 'lstat')
# 6 features:  ('nox', 'dis', 'rad', 'tax', 'ptratio', 'lstat')
# 5 features:  ('nox', 'dis', 'rad', 'ptratio', 'lstat')
# 4 features:  ('nox', 'dis', 'ptratio', 'lstat')
# 3 features:  ('dis', 'ptratio', 'lstat')
# 2 features:  ('ptratio', 'lstat')
# 1 features:  ('lstat',)

# %% [markdown]
# ## (怎么做Justify 是否为8和10）TODO 1: Try to do forward/backward stepwise selection on all 13 features. What is the "best" subset based on your own understanding? Write down the number of features and their names. Please justify your choice.
#
# You can leverage the code above

# %%
# you code here
X = df_data[all_features]
y = df_data["medv"]

# %%
lr = LinearRegression()

sfs_forward = SequentialFeatureSelector(lr, 
          k_features='best',
          forward=True, 
          floating=False, 
          scoring='neg_mean_squared_error',
          cv=5)

sfs_forward = sfs_forward.fit(X, y)
fig_forward = plot_sequential_feature_selection(sfs_forward.get_metric_dict(), kind='std_err')

plt.title('Sequential Forward Selection (w. StdErr)')
plt.grid()
plt.ylim((-60,-20))
plt.show()

for k, items in sfs_forward.subsets_.items():
    print(f"{k} features (forward): ", items["feature_names"])
# Out:
# 1 features (forward):  ('lstat',)
# 2 features (forward):  ('ptratio', 'lstat')
# 3 features (forward):  ('rm', 'ptratio', 'lstat')
# 4 features (forward):  ('chas', 'rm', 'ptratio', 'lstat')
# 5 features (forward):  ('crim', 'chas', 'rm', 'ptratio', 'lstat')
# 6 features (forward):  ('crim', 'chas', 'rm', 'dis', 'ptratio', 'lstat')
# 7 features (forward):  ('crim', 'indus', 'chas', 'rm', 'dis', 'ptratio', 'lstat')
# 8 features (forward):  ('crim', 'zn', 'indus', 'chas', 'rm', 'dis', 'ptratio', 'lstat')
# 9 features (forward):  ('crim', 'zn', 'indus', 'chas', 'rm', 'dis', 'ptratio', 'b', 'lstat')
# 10 features (forward):  ('crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'dis', 'ptratio', 'b', 'lstat')
# 11 features (forward):  ('crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'ptratio', 'b', 'lstat')
# 12 features (forward):  ('crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'tax', 'ptratio', 'b', 'lstat')
# 13 features (forward):  ('crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax', 'ptratio', 'b', 'lstat')

# %%
print("Best subset (forward selection):", sfs_forward.k_feature_names_)
# Out:
# Best subset (forward selection): ('crim', 'zn', 'indus', 'chas', 'rm', 'dis', 'ptratio', 'lstat')

# %% [markdown]
# In the plot, the performance seems to plateau around 8 features, after which there is no significant improvement in performance with the addition of more features. The performance might even be starting to slightly decrease after 9 features, suggesting that further addition of features might lead to overfitting or that these additional features do not contribute significantly to the model.
#
# Given these observations, I would suggest that the subset of 8 features might be the "best" choice, balancing the complexity and performance. These features are 'crim', 'indus', 'chas', 'rm', 'dis', 'ptratio', 'lstat'.
#
# The justification for this choice is primarily the plot where the performance metric does not significantly improve after 8 features. This indicates that the selected subset is likely to provide a good trade-off between model accuracy and complexity. Including more features beyond this point might lead to a more complex model without a commensurate gain in performance, which is undesirable in most modeling contexts.

# %%
lr = LinearRegression()

sfs_backward = SequentialFeatureSelector(lr, 
          k_features='best',
          forward=False, 
          floating=False, 
          scoring='neg_mean_squared_error',
          cv=5)

sfs_backward = sfs_backward.fit(X, y)
fig_backward = plot_sequential_feature_selection(sfs_backward.get_metric_dict(), kind='std_err')

plt.title('Sequential Backward Selection (w. StdErr)')
plt.ylim((-60,-20))
plt.grid()
plt.show()

for k, items in sfs_backward.subsets_.items():
    print(f"{k} features: ", items["feature_names"])
# Out:
# 13 features:  ('crim', 'zn', 'indus', 'chas', 'nox', 'rm', 'age', 'dis', 'rad', 'tax', 'ptratio', 'b', 'lstat')
# 12 features:  ('crim', 'zn', 'indus', 'chas', 'nox', 'age', 'dis', 'rad', 'tax', 'ptratio', 'b', 'lstat')
# 11 features:  ('crim', 'zn', 'chas', 'nox', 'age', 'dis', 'rad', 'tax', 'ptratio', 'b', 'lstat')
# 10 features:  ('crim', 'zn', 'nox', 'age', 'dis', 'rad', 'tax', 'ptratio', 'b', 'lstat')
# 9 features:  ('crim', 'zn', 'nox', 'dis', 'rad', 'tax', 'ptratio', 'b', 'lstat')
# 8 features:  ('zn', 'nox', 'dis', 'rad', 'tax', 'ptratio', 'b', 'lstat')
# 7 features:  ('zn', 'nox', 'dis', 'rad', 'tax', 'ptratio', 'lstat')
# 6 features:  ('nox', 'dis', 'rad', 'tax', 'ptratio', 'lstat')
# 5 features:  ('nox', 'dis', 'rad', 'ptratio', 'lstat')
# 4 features:  ('nox', 'dis', 'ptratio', 'lstat')
# 3 features:  ('dis', 'ptratio', 'lstat')
# 2 features:  ('ptratio', 'lstat')
# 1 features:  ('lstat',)

# %%
print(f"Best subset (backward selection): {sfs_backward.k_feature_names_}")
# Out:
# Best subset (backward selection): ('crim', 'zn', 'nox', 'age', 'dis', 'rad', 'tax', 'ptratio', 'b', 'lstat')

# %% [markdown]
# From the plot, we can see that the performance increases as features are removed from 13 down to 10, suggesting that some features may be contributing noise or are not informative. As features continue to be removed beyond 10, the performance begins to decrease slightly, which may indicate the loss of informative variables.
#
# According to the results from the print statement and the plot, which likely indicates the output of the backward selection algorithm, the "best" subset consists of 10 features. These are
# 'crim', 'zn', 'nox', 'age', 'dis', 'rad', 'tax', 'ptratio', 'b', 'lstat'.
#
# The justification for choosing this subset is that it represents the point at which the model's performance is high before it begins to decrease with the removal of more features, according to the plot. This suggests that each feature in the subset likely adds valuable information that aids in the performance of the model.

# %% [markdown]
# # Ridge regression and Lasso regression

# %%
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import Ridge, Lasso

# %%
X = df_data[all_features]
y = df_data["medv"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
clf_lr = Pipeline([
    ('std_scaler', StandardScaler()),
    ('L_regressor',LinearRegression()),
])

# %%
clf_lr.fit(X_train,y_train)
y_pred_lr = clf_lr.predict(X_test)
print("------LR------")
print("LR train R2 score: %0.6f" % clf_lr.score(X_train, y_train))
print("LR test R2 score: %0.6f" % clf_lr.score(X_test, y_test))
print(clf_lr.named_steps['L_regressor'].coef_)
# Out:
# ------LR------
# LR train R2 score: 0.739234
# LR test R2 score: 0.726157
# [-0.98858032  0.86793276  0.40502822  0.86183791 -1.90009974  2.80813518
#  -0.35866856 -3.04553498  2.03276074 -1.36400909 -2.0825356   1.04125684
#  -3.92628626]

# %% [markdown]
# ## Ridge Regression

# %%
clf_ridge = Pipeline([
    ('std_scaler', StandardScaler()),
    ('L_regressor', Ridge(alpha=0.1)),
]) 

clf_ridge.fit(X_train,y_train)
y_pred_ridge = clf_ridge.predict(X_test)
print("------Ridge------")
print("Ridge train R2 score: %0.6f" % clf_ridge.score(X_train, y_train))
print("Ridge test R2 score: %0.6f" % clf_ridge.score(X_test, y_test))
print(clf_ridge.named_steps['L_regressor'].coef_)
# Out:
# ------Ridge------
# Ridge train R2 score: 0.739234
# Ridge test R2 score: 0.726120
# [-0.98722604  0.86567745  0.40197774  0.86241287 -1.89608318  2.80888802
#  -0.35892745 -3.04108762  2.02423176 -1.35675167 -2.08123083  1.04099697
#  -3.92476674]

# %%
plt.plot(clf_lr.named_steps['L_regressor'].coef_, label = "lr")
plt.plot(clf_ridge.named_steps['L_regressor'].coef_, label = "ridge")
plt.hlines(y = 0, xmin = 0, xmax = 13)
plt.legend()
plt.show()

# %%
# a larger lambda will push coefficient towards zero
clf_ridge = Pipeline([
    ('std_scaler', StandardScaler()),
    ('L_regressor', Ridge(alpha=100)),
]) 

clf_ridge.fit(X_train,y_train)
y_pred_ridge = clf_ridge.predict(X_test)
print("------Ridge------")
print("Ridge train R2 score: %0.6f" % clf_ridge.score(X_train, y_train))
print("Ridge test R2 score: %0.6f" % clf_ridge.score(X_test, y_test))
print(clf_ridge.named_steps['L_regressor'].coef_)
# Out:
# ------Ridge------
# Ridge train R2 score: 0.711332
# Ridge test R2 score: 0.696690
# [-0.62465551  0.36705687 -0.23889316  0.94899585 -0.70011357  2.6925179
#  -0.32541473 -1.31245885  0.29116678 -0.36977324 -1.54579918  0.85266916
#  -2.95976482]

# %%
plt.plot(clf_lr.named_steps['L_regressor'].coef_, label = "lr")
plt.plot(clf_ridge.named_steps['L_regressor'].coef_, label = "ridge")
plt.hlines(y = 0, xmin = 0, xmax = 13)
plt.legend()
plt.show()

# %% [markdown]
# ## Lasso Regression

# %%
clf_lasso = Pipeline([
    ('std_scaler', StandardScaler()),
    ('L_regressor',Lasso(alpha=0.1)),
]) 

clf_lasso.fit(X_train,y_train)
y_pred_lasso = clf_lasso.predict(X_test)
print("------Lasso------")
print("Lasso train R2 score: %0.6f" % clf_lasso.score(X_train, y_train))
print("Lasso test R2 score: %0.6f" % clf_lasso.score(X_test, y_test))
print(clf_lasso.named_steps['L_regressor'].coef_)
# Out:
# ------Lasso------
# Lasso train R2 score: 0.733414
# Lasso test R2 score: 0.711239
# [-0.66991383  0.43061628 -0.          0.87630476 -1.36149475  2.89584589
#  -0.18487001 -2.25812838  0.46253968 -0.         -1.90039821  0.9373862
#  -3.95913625]

# %%
plt.plot(clf_lr.named_steps['L_regressor'].coef_, label = "lr")
plt.plot(clf_ridge.named_steps['L_regressor'].coef_, label = "ridge")
plt.plot(clf_lasso.named_steps['L_regressor'].coef_, label = "lasso")
plt.hlines(y = 0, xmin = 0, xmax = 13)
plt.legend()
plt.show()

# %%
# Select features with larger lambda (named alpha in sklearn library)
clf_lasso = Pipeline([
    ('std_scaler', StandardScaler()),
    ('L_regressor',Lasso(alpha=1)),
]) 

clf_lasso.fit(X_train,y_train)
y_pred_lasso = clf_lasso.predict(X_test)
print("------Lasso------")
print("Lasso train R2 score: %0.6f" % clf_lasso.score(X_train, y_train))
print("Lasso test R2 score: %0.6f" % clf_lasso.score(X_test, y_test))
print(clf_lasso.named_steps['L_regressor'].coef_)
# Out:
# ------Lasso------
# Lasso train R2 score: 0.672413
# Lasso test R2 score: 0.654243
# [-0.          0.         -0.          0.27140271 -0.          2.62932147
#  -0.         -0.         -0.         -0.         -1.21106809  0.29872625
#  -3.81788375]

# %%
plt.plot(clf_lr.named_steps['L_regressor'].coef_, label = "lr")
plt.plot(clf_ridge.named_steps['L_regressor'].coef_, label = "ridge")
plt.plot(clf_lasso.named_steps['L_regressor'].coef_, label = "lasso")
plt.hlines(y = 0, xmin = 0, xmax = 13)
plt.legend()
plt.show()

# %% [markdown]
# ## Coefficient Profiles

# %%
n_alphas = 200
alphas = np.logspace(-2, 6, n_alphas)
coefs = []
for a in alphas:
    ridge = Pipeline([
        ('std_scaler', StandardScaler()),
        ('L_regressor', Ridge(alpha=a)),
    ]) 
#     ridge = Ridge(alpha=a, fit_intercept=False)
    ridge.fit(X, y)
    coefs.append(ridge.named_steps['L_regressor'].coef_)

    ax = plt.gca()

ax.plot(alphas, coefs)
ax.set_xscale('log')
ax.set_xlim(ax.get_xlim()[::-1])  # reverse axis
plt.xlabel('alpha (lambda)')
plt.ylabel('weights')
plt.title('Ridge coefficients as a function of the regularization')
plt.axis('tight')
plt.axvline(1, c='red')
plt.axvline(100, c='blue')

# %%
n_alphas = 200
alphas = np.logspace(-2, 2, n_alphas)
coefs = []
for a in alphas:
    ridge = Pipeline([
        ('std_scaler', StandardScaler()),
        ('L_regressor', Lasso(alpha=a)),
    ]) 
#     ridge = Ridge(alpha=a, fit_intercept=False)
    ridge.fit(X, y)
    coefs.append(ridge.named_steps['L_regressor'].coef_)

    ax = plt.gca()

ax.plot(alphas, coefs)
ax.set_xscale('log')
ax.set_xlim(ax.get_xlim()[::-1])  # reverse axis
plt.xlabel('alpha (lambda)')
plt.ylabel('weights')
plt.title('Lasso coefficients as a function of the regularization')
plt.axis('tight')
plt.axvline(1, c='red')
plt.axvline(0.1, c='blue')

# %% [markdown]
# ## TODO 2: Using your choice of the feature subset in TODO 1, plot out the coefficient profiles for both Ridge Regression and Lasso Regression. If you are going to decide the alpha (i.e., lambda) value for the two regression models, what values will you choose? And why?

# %%
# Your code here
from sklearn.linear_model import RidgeCV, LassoCV

# %%
forward_subset = ['crim', 'zn', 'indus', 'chas', 'rm', 'dis', 'ptratio', 'lstat']
backward_subset = ['crim', 'zn', 'nox', 'age', 'dis', 'rad', 'tax', 'ptratio', 'b', 'lstat']

# %%
X_subset = df_data[forward_subset]

# %%
scaler = StandardScaler()
X_subset_standardized = scaler.fit_transform(X_subset)

# %%
n_alphas = 200
alphas = np.logspace(-2, 6, n_alphas)

# %%
ridge_coefs = []
for a in alphas:
    ridge = Ridge(alpha=a)
    ridge.fit(X_subset_standardized, y)
    ridge_coefs.append(ridge.coef_)

# %% [markdown]
# # 这个step是否要加

# %%
# RidgeCV
ridge_alphas = np.logspace(-2, 6, n_alphas)
ridge_cv = RidgeCV(alphas=ridge_alphas, store_cv_values=True)
ridge_cv.fit(X_subset_standardized, y)
ridge_best_alpha = ridge_cv.alpha_
print(f'Optimal alpha for Ridge: {ridge_best_alpha}')
# Out:
# Optimal alpha for Ridge: 12.458833642950081

# %%
plt.figure(figsize=(14, 7))
plt.subplot(121)
plt.plot(alphas, ridge_coefs)
plt.xscale('log')
plt.gca().invert_xaxis()
plt.xlabel('alpha (lambda)')
plt.ylabel('weights')
plt.title('Ridge Coefficients')
plt.axis('tight')
# Out:
# (2511886.4315095823,
#  0.003981071705534973,
#  -4.553515723508308,
#  3.1620140179163663)

# %%
lasso_coefs = []
for a in alphas:
    lasso = Lasso(alpha=a)
    lasso.fit(X_subset_standardized, y)
    lasso_coefs.append(lasso.coef_)

# %% [markdown]
# # 这个step是否要加

# %%
# LassoCV
lasso_cv = LassoCV(alphas=alphas, max_iter=10000, cv=5)
lasso_cv.fit(X_subset_standardized, y)
lasso_best_alpha = lasso_cv.alpha_
print(f'Optimal alpha for Lasso: {lasso_best_alpha}')
# Out:
# Optimal alpha for Lasso: 0.01

# %%
plt.subplot()
plt.plot(alphas, lasso_coefs)
plt.xscale('log')
plt.gca().invert_xaxis()
plt.xlabel('alpha (lambda)')
plt.ylabel('weights')
plt.title('Lasso Coefficients')
plt.axis('tight')
plt.show()

# %% [markdown]
# # 值可能要更改
# For the Ridge regression model, I would choose an alpha where the coefficient paths start to plateau before becoming completely flat, indicating a good balance between bias and variance. Based on the plot, this might be around an alpha of 10.
#
# For the Lasso regression model, I would select an alpha that is just large enough to eliminate the least significant features, which occurs at the point where the coefficient paths sharply drop to zero. Again, this is approximately at an alpha of 0.01.
